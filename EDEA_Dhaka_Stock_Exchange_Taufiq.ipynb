# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Taufiq-Khan/Web-Scraping-Dhaka-Stock-Exchange/blob/main/EDEA_Dhaka_Stock_Exchange_Taufiq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
url = "https://raw.githubusercontent.com/Muhammad-Taufiq-Khan/Web-Scraping-Dhaka-Stock-Exchange/main/DSE%20Scraped%20Data_Taufiq.csv"
df = pd.read_csv(url)
df
# Out:
#     Trading Code                     Company Name Last Trading Price  \
# 0      1JANATAMF    First Janata Bank Mutual Fund               6.20
# 1     1STPRIMFMF  Prime Finance First Mutual Fund              17.30
# 2       AAMRANET           aamra networks limited              38.70
# 3      AAMRATECH       aamra technologies limited              31.10
# 4       ABB1STMF          AB Bank 1st Mutual fund               5.20
# ..           ...                              ...                ...
# 379   WMSHIPYARD  Western Marine Shipyard Limited              11.40
# 380          YPL           Yeakin Polymer Limited              18.80
# 381   ZAHEENSPIN          Zaheen Spinning Limited              12.60
# 382     ZAHINTEX      Zahintex Industries Limited               9.20
# 383   ZEALBANGLA     Zeal Bangla Sugar Mills Ltd.             177.50
#
#     Closing Price Last Update      Day's Range Change* Day's Value (mn)  \
# ...

# %% [markdown]
# * **Last Trading Price:** Updated price of last trade.
#
# * **Closing Price:** The last price when trading day was end.
#
# * **Day's Range:** Lowest and Highest price of the day
#
# * **Change:**
#
# * **Day's Value (mn):**
#
# * **Day's Volume:** How many shares has been traded tody
#
# * **Change(%):**
#
# * **52 Weeks' Moving Range:**  Lowest and Highest price of last 52 weeks
#
# * **Day's Trade:**
#
# * **Market Capitalization (mn):**
#
# * **Authorized Capital (mn):**
#
# * **Debut Trading Date:** Date of 1st trade in Stock market.
#
# * **Paid-up Capital (mn):**
#
# *  **Face par value:** Original cost per stock, which should be paid to the holder.
#
# *   **Total No. of Outstanding Securities:** Remaining Security Balence held by company.

# %%
HEADER = ['Trading Code',
 'Company Name',
 'Last Trading Price',
 'Closing Price',
 'Last Update',
 "Day's Range",
 'Change*',
 "Day's Value (mn)",
 'Change(%)',
 "52 Weeks' Moving Range",
 'Opening Price',
 "Day's Volume (Nos.)",
 'Adjusted Opening Price',
 "Day's Trade (Nos.)",
 "Yesterday's Closing Price",
 'Market Capitalization (mn)',
 'Authorized Capital (mn)',
 'Debut Trading Date',
 'Paid-up Capital (mn)',
 'Type of Instrument',
 'Face/par Value',
 'Market Lot',
 'Total No. of Outstanding Securities',
 'Sector',
 'Address',
 'Contact Phone',
 'Fax',
 'E-mail',
 'Web Address',
 'Company Secretary Name',
 'Cell No.',
 'Telephone No.',
 'E-mail']
len(HEADER)

# %%
df.isnull().sum()
# Out:
# Trading Code                             0
# Company Name                             0
# Last Trading Price                       0
# Closing Price                            0
# Last Update                              0
# Day's Range                              0
# Change*                                  0
# Day's Value (mn)                         0
# Change(%)                                0
# 52 Weeks' Moving Range                   0
# Opening Price                            0
# Day's Volume (Nos.)                      0
# Adjusted Opening Price                   0
# Day's Trade (Nos.)                       0
# Yesterday's Closing Price                0
# Market Capitalization (mn)               0
# Authorized Capital (mn)                  0
# Debut Trading Date                     251
# Paid-up Capital (mn)                     0
# Type of Instrument                       0
# Face/par Value                           0
# Market Lot                               0
# ...

# %%
df.dtypes
# Out:
# Trading Code                            object
# Company Name                            object
# Last Trading Price                      object
# Closing Price                           object
# Last Update                             object
# Day's Range                             object
# Change*                                 object
# Day's Value (mn)                        object
# Change(%)                               object
# 52 Weeks' Moving Range                  object
# Opening Price                           object
# Day's Volume (Nos.)                     object
# Adjusted Opening Price                  object
# Day's Trade (Nos.)                      object
# Yesterday's Closing Price               object
# Market Capitalization (mn)              object
# Authorized Capital (mn)                 object
# Debut Trading Date                      object
# Paid-up Capital (mn)                    object
# Type of Instrument                      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Trading Code                         384 non-null    object
#  1   Company Name                         384 non-null    object
#  2   Last Trading Price                   384 non-null    object
#  3   Closing Price                        384 non-null    object
#  4   Last Update                          384 non-null    object
#  5   Day's Range                          384 non-null    object
#  6   Change*                              384 non-null    object
#  7   Day's Value (mn)                     384 non-null    object
#  8   Change(%)                            384 non-null    object
#  9   52 Weeks' Moving Range               384 non-null    object
#  10  Opening Price                        384 non-null    object
# ...

# %%
##Count and show unique values per Attribute
for i in (df):
  print(f"Attribute Name: {i}\n
  Total Unique Value: {df[i].nunique()}\n
  Unique Values: {df[i].unique()}\n")
# Out:
# Attribute Name: Trading Code
# Total Unique Value: 384
# Unique Values: ['1JANATAMF' '1STPRIMFMF' 'AAMRANET' 'AAMRATECH' 'ABB1STMF' 'ABBANK'
#  'ACFL' 'ACI' 'ACIFORMULA' 'ACMELAB' 'ACMEPL' 'ACTIVEFINE' 'ADNTEL'
#  'ADVENT' 'AFCAGRO' 'AFTABAUTO' 'AGNISYSL' 'AGRANINS' 'AIBL1STIMF'
#  'AIBLPBOND' 'AIL' 'AL-HAJTEX' 'ALARABANK' 'ALIF' 'ALLTEX' 'AMANFEED'
#  'AMBEEPHA' 'AMCL(PRAN)' 'ANLIMAYARN' 'ANWARGALV' 'AOL' 'APEXFOODS'
#  'APEXFOOT' 'APEXSPINN' 'APEXTANRY' 'APOLOISPAT' 'ARAMIT' 'ARAMITCEM'
#  'ARGONDENIM' 'ASIAINS' 'ASIAPACINS' 'ATCSLGF' 'ATLASBANG' 'AZIZPIPES'
#  'BANGAS' 'BANKASIA' 'BARKAPOWER' 'BATASHOE' 'BATBC' 'BAYLEASING' 'BBS'
#  'BBSCABLES' 'BDAUTOCA' 'BDCOM' 'BDFINANCE' 'BDLAMPS' 'BDTHAI'
#  'BDTHAIFOOD' 'BDWELDING' 'BEACHHATCH' 'BEACONPHAR' 'BENGALWTL'
#  'BERGERPBL' 'BEXGSUKUK' 'BEXIMCO' 'BGIC' 'BIFC' 'BNICL' 'BPML' 'BPPL'
#  'BRACBANK' 'BSC' 'BSCCL' 'BSRMLTD' 'BSRMSTEEL' 'BXPHARMA' 'CAPMBDBLMF'
#  'CAPMIBBLMF' 'CENTRALINS' 'CENTRALPHL' 'CITYBANK' 'CITYGENINS' 'CNATEX'
# ...

# %%
# # Logic Snippet
# import numpy as np

# ar = [[1,2],
#       [3,"-"]]
# for row in ar:
#     for i, ele in enumerate(row):
#         if ele == "-":
#             row[i] = np.NaN
# print(ar)
# df["Sector"][0]
# Out:
# [[1, 2], [3, nan]]

# %%
import numpy as np
stock_data = df.copy()
count = 0

for col in stock_data:
    for i, data in enumerate(stock_data[col]):
        if data == "-":
            stock_data[col][i] = np.NaN
            count+=1
            print(f"{count}. Replaced with NaN in {i}th of {col}")
# Out:
# 1. Replaced with NaN in 112th of Last Trading Price
# 2. Replaced with NaN in 112th of Closing Price
# 3. Replaced with NaN in 112th of Day's Range
# 4. Replaced with NaN in 112th of Change*
# 5. Replaced with NaN in 112th of Day's Value (mn)
# 6. Replaced with NaN in 112th of Change(%)
# 7. Replaced with NaN in 112th of Opening Price
# 8. Replaced with NaN in 112th of Day's Volume (Nos.)
# 9. Replaced with NaN in 112th of Adjusted Opening Price
# 10. Replaced with NaN in 112th of Day's Trade (Nos.)
# 11. Replaced with NaN in 112th of Yesterday's Closing Price
# 12. Replaced with NaN in 0th of Authorized Capital (mn)
# 13. Replaced with NaN in 1th of Authorized Capital (mn)
# 14. Replaced with NaN in 4th of Authorized Capital (mn)
# 15. Replaced with NaN in 18th of Authorized Capital (mn)
# 16. Replaced with NaN in 19th of Authorized Capital (mn)
# 17. Replaced with NaN in 41th of Authorized Capital (mn)
# 18. Replaced with NaN in 63th of Authorized Capital (mn)
# ...

# %%
print(df.info()); print('\n'); print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Trading Code                         384 non-null    object
#  1   Company Name                         384 non-null    object
#  2   Last Trading Price                   384 non-null    object
#  3   Closing Price                        384 non-null    object
#  4   Last Update                          384 non-null    object
#  5   Day's Range                          384 non-null    object
#  6   Change*                              384 non-null    object
#  7   Day's Value (mn)                     384 non-null    object
#  8   Change(%)                            384 non-null    object
#  9   52 Weeks' Moving Range               384 non-null    object
#  10  Opening Price                        384 non-null    object
# ...

# %%
print(stock_data.isnull().sum()); print('\n'); print(stock_data.info());
# Out:
# Trading Code                             0
# Company Name                             0
# Last Trading Price                       1
# Closing Price                            1
# Last Update                              0
# Day's Range                              1
# Change*                                  1
# Day's Value (mn)                         1
# Change(%)                                1
# 52 Weeks' Moving Range                   0
# Opening Price                            1
# Day's Volume (Nos.)                      1
# Adjusted Opening Price                   1
# Day's Trade (Nos.)                       1
# Yesterday's Closing Price                1
# Market Capitalization (mn)               0
# Authorized Capital (mn)                 38
# Debut Trading Date                     251
# Paid-up Capital (mn)                     0
# Type of Instrument                       0
# Face/par Value                           0
# Market Lot                               0
# ...

# %%
df.shape, len(df)
# Out:
# ((384, 33), 384, (384, 33), 384)

# %%
stock_data.shape, len(stock_data)
# Out:
# ((384, 33), 384)

# %%
df.loc[:, HEADER].shape
# Out:
# (384, 33)

# %%
from numpy import NaN
data = [[1,2,3,4, NaN],
       ["Abba1", 2, "1.5- 1.5", "Alal", "-"]]

Header = ["A","b","c","d","e"]

df_test = pd.DataFrame(data,columns = Header)
df_test
# Out:
#        A  b         c     d    e
# 0      1  2         3     4  NaN
# 1  Abba1  2  1.5- 1.5  Alal    -

# %%
df_test.isnull().sum()
# Out:
# A    0
# b    0
# c    0
# d    0
# e    1
# dtype: int64
